# %%
from ThreeSweep import ThreeSweep
threesweep = ThreeSweep()
threesweep.loadImage('inputs/Sample1.png')
threesweep.matlabCode()
# threesweep.showImage()
# Out:
# [array([[[310, 553]],
#
#        [[316, 553]]], dtype=int32), array([[[264, 553]],
#
#        [[268, 553]]], dtype=int32), array([[[321, 552]],
#
#        [[325, 552]]], dtype=int32), array([[[257, 552]],
#
#        [[260, 552]]], dtype=int32), array([[[333, 551]],
#
#        [[335, 551]]], dtype=int32), array([[[251, 551]],
#
#        [[252, 551]]], dtype=int32), array([[[337, 550]],
#
#        [[340, 550]]], dtype=int32), array([[[248, 550]],
#
#        [[249, 550]]], dtype=int32), array([[[344, 549]],
#
#        [[345, 549]]], dtype=int32), array([[[244, 549]]], dtype=int32), array([[[347, 548]]], dtype=int32), array([[[242, 548]]], dtype=int32), array([[[351, 546]],
#
#        [[350, 547]],
#
#        [[349, 547]],
#
#        [[350, 547]]], dtype=int32), array([[[360, 538]],
#
#        [[353, 545]]], dtype=int32), array([[[230, 538]],
#
#        [[231, 539]],
#
#        [[231, 540]],
#
#        [[236, 545]],
#
#        [[237, 545]],
#
#        [[239, 547]],
#
# ...
